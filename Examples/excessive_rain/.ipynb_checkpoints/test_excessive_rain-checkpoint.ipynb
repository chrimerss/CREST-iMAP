# %%
import anuga
from osgeo import gdal
from glob import glob
from affine import Affine
import geopandas as gpd

# %matplotlib inline

# Allow inline jshtml animations
from matplotlib import rc
rc('animation', html='jshtml')

# %%
bounding_polygon= gpd.read_file('area/domain.shp')

# Elevation Data
topography_file = 'DEM.tif'
# topography_file= '/home/ZhiLi/CRESTHH/data/precip/imerg20170825S150000.tif'

# Resolution for most of the mesh
base_resolution = 0.001  # m^2

# %%
domain = anuga.create_domain_from_regions(
            list(bounding_polygon.exterior[0].coords),
            boundary_tags={'bottom': [0],},
            maximum_triangle_area=base_resolution,
            
            )

# Basic geometry and bounding polygon
# xleft   = 0
# xright  = 5.448
# ybottom = 0
# ytop    = 3.402

# point_sw = [xleft, ybottom]
# point_se = [xright, ybottom]
# point_nw = [xleft, ytop]    
# point_ne = [xright, ytop]

# bounding_polygon = [point_se,
#                     point_ne,
#                     point_nw,
#                     point_sw]



# domain= anuga.create_domain_from_rectangular()

domain.set_name('excessive_rain') # Name of sww file
dplotter = anuga.Domain_plotter(domain)  
plt.triplot(dplotter.triang, linewidth = 0.4);
# Out:
# Figure files for each frame will be stored in _plot

# %%
print 'Number of elements:',domain.number_of_elements
# Out:
# Number of elements: 1032

# %%
from osgeo import gdal

# %%
domain.set_quantity('elevation', filename=topography_file, location='centroids') # Use function for elevation
domain.set_quantity('friction', 0.01, location='centroids')                        # Constant friction 
domain.set_quantity('stage', expression='elevation', location='centroids')         # Dry Bed 
domain.set_quantity('RI', 0.5, location='centroids')
domain.set_quantity('RS', 0.5, location='centroids')
domain.set_quantity('SS0', 0.5, location='centroids')
domain.set_quantity('SI0', 0.5, location='centroids')
domain.set_quantity('W0', 0.5, location='centroids')
domain.set_quantity('RainFact', 0.5, location='centroids')
domain.set_quantity('Ksat', 0.5, location='centroids')
domain.set_quantity('WM', 0.5, location='centroids')
domain.set_quantity('B', 0.5, location='centroids')
domain.set_quantity('IM', 0.5, location='centroids')
domain.set_quantity('KE', 0.5, location='centroids')
domain.set_quantity('coeM', 0.5, location='centroids')
domain.set_quantity('expM', 0.5, location='centroids')
domain.set_quantity('coeR', 0.5, location='centroids')
domain.set_quantity('coeS', 0.5, location='centroids')
domain.set_quantity('KS', 0.5, location='centroids')
domain.set_quantity('KI', 0.5, location='centroids')
domain.set_evap_dir('/home/ZhiLi/CRESTHH/data/evap', pattern='imerg%Y%m%dS%H%M%S.tif')
domain.set_precip_dir('/home/ZhiLi/CRESTHH/data/precip',pattern='imerg%Y%m%dS%H%M%S.tif')
domain.set_timestamp('20170825060000', format='%Y%m%d%H%M%S')
domain.set_time_interval('1H')

plt.tripcolor(dplotter.triang, 
              facecolors = dplotter.elev, 
              cmap='Greys_r')
plt.colorbar();
plt.title("Elevation");

# %%
Br = anuga.Reflective_boundary(domain)
Bt = anuga.Transmissive_boundary(domain)

domain.set_boundary({'bottom':   Bt,
                     'exterior': Br})

# %%
coords= list(bounding_polygon.exterior[0].coords)

# %%
# Rain = anuga.Quantity(domain, name='Rain')
# ET= anuga.Quantity(domain, name='ET')
# forcing_op= anuga.Rate_operator(domain, rate=Rain+ET)
# rain_op = anuga.Rate_operator(domain, rate = Rain)
# et_op = anuga.Rate_operator(domain, rate= Evap)
# Rain= anuga.Rate_operator(domain, rate=lambda t: 5 if t<5 else 10)
for i,t in enumerate(domain.evolve(yieldstep=0.1, duration=10)):
#     current_rain_file = sorted(glob(external_dir+'/*.tif'))[i]
#     print(current_rain_file)
#     Rain.set_values_from_utm_grid_file(current_rain_file, location='centroids')
#     ET.set_values_from_utm_grid_file(current_rain_file, location='centroids')
    #dplotter.plot_depth_frame()
    dplotter.save_depth_frame(vmin=0.0, vmax=1)
#     domain.print_operator_timestepping_statistics()
#     domain.print_timestepping_statistics()
#     domain.report_water_volume_statistics()

    stage = domain.get_quantity('stage')
    elev  = domain.get_quantity('elevation')
    height = stage - elev
    print 'integral = ', height.get_integral()    
# Read in the png files stored during the evolve loop
dplotter.make_depth_animation()
# Out:
# integral =  9.578509692826557e-18
# 2017-08-25 06:00:00 /home/ZhiLi/CRESTHH/data/precip/imerg20170825S060000.tif /home/ZhiLi/CRESTHH/data/precip/imerg20170825S060000.tif
# 2017-08-25 07:00:00 /home/ZhiLi/CRESTHH/data/precip/imerg20170825S070000.tif /home/ZhiLi/CRESTHH/data/precip/imerg20170825S070000.tif
# 2017-08-25 09:00:00 /home/ZhiLi/CRESTHH/data/precip/imerg20170825S090000.tif /home/ZhiLi/CRESTHH/data/precip/imerg20170825S090000.tif
# 2017-08-25 12:00:00 /home/ZhiLi/CRESTHH/data/precip/imerg20170825S120000.tif /home/ZhiLi/CRESTHH/data/precip/imerg20170825S120000.tif
# 2017-08-25 16:00:00 /home/ZhiLi/CRESTHH/data/precip/imerg20170825S160000.tif /home/ZhiLi/CRESTHH/data/precip/imerg20170825S160000.tif
# 2017-08-25 21:00:00 /home/ZhiLi/CRESTHH/data/precip/imerg20170825S210000.tif /home/ZhiLi/CRESTHH/data/precip/imerg20170825S210000.tif
# 2017-08-26 03:00:00 /home/ZhiLi/CRESTHH/data/precip/imerg20170826S030000.tif /home/ZhiLi/CRESTHH/data/precip/imerg20170826S030000.tif
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-9bdb44b39a3e> in <module>()
#       5 # et_op = anuga.Rate_operator(domain, rate= Evap)
#       6 # Rain= anuga.Rate_operator(domain, rate=lambda t: 5 if t<5 else 10)
# ----> 7 for i,t in enumerate(domain.evolve(yieldstep=0.1, duration=10)):
#       8 #     current_rain_file = sorted(glob(external_dir+'/*.tif'))[i]
#       9 #     print(current_rain_file)
#
# /home/ZhiLi/CRESTHH/python2/lib/python2.7/site-packages/anuga/shallow_water/shallow_water_domain.pyc in evolve(self, yieldstep, finaltime, duration, skip_initial_step)
#    2444         for t in self._evolve_base(yieldstep=yieldstep,
#    2445                                    finaltime=finaltime, duration=duration,
# -> 2446                                    skip_initial_step=skip_initial_step):
#    2447
#    2448             self.yieldstep_id += 1
#
# /home/ZhiLi/CRESTHH/python2/lib/python2.7/site-packages/anuga/abstract_2d_finite_volumes/generic_domain.pyc in _evolve_base(self, yieldstep, finaltime, duration, skip_initial_step)
#    1789
#    1790             self.quantities['P'].set_values_from_utm_grid_file(precip_pth,
# -> 1791                              location='centroids')
#    1792             self.quantities['ET'].set_values_from_utm_grid_file(evap_pth,
#    1793                              location='centroids')
#
# /home/ZhiLi/CRESTHH/python2/lib/python2.7/site-packages/anuga/abstract_2d_finite_volumes/quantity.pyc in set_values_from_utm_grid_file(self, filename, location, indices, verbose)
#    1344             x,y,Z = dem2array(filename)
#    1345         elif filename_ext == '.tif':
# -> 1346             x,y,Z= tif2array(filename)
#    1347         else:
#    1348             msg= 'The file extension is not suportted... Only .asc, .grd, .dem, .tif are supported.'
#
# /home/ZhiLi/CRESTHH/python2/lib/python2.7/site-packages/anuga/file_conversion/tif2array.pyc in tif2array(filename, variable_name, easting_min, easting_max, northing_min, northing_max, use_cache, verbose)
#      10     import os
#      11     raster= gdal.Open(filename)
# ---> 12     ncols= raster.RasterXSize
#      13     nrows= raster.RasterYSize
#      14     x_origin, x_res, _, y_origin, _, y_res= raster.GetGeoTransform()
#
# AttributeError: 'NoneType' object has no attribute 'RasterXSize'

# %%
swwfile = 'excessive_rain_para.sww'
splotter = anuga.SWW_plotter(swwfile)


# Plot Depth and Speed at the last time slice
plt.subplot(121)
splotter.triang.set_mask(None)
plt.tripcolor(splotter.triang, 
              facecolors = splotter.depth[-1,:], 
              cmap='viridis')

plt.title("Depth")


plt.subplot(122)
splotter.triang.set_mask(None)
plt.tripcolor(splotter.triang, 
              facecolors = splotter.speed[-1,:], 
              cmap='viridis')

plt.title("Speed");

# %%
swwfile = 'excessive_rain_para.sww'
splotter = anuga.SWW_plotter(swwfile)


# Plot Depth and Speed at the last time slice
plt.subplot(121)
splotter.triang.set_mask(None)
plt.tripcolor(splotter.triang, 
              facecolors = splotter.depth[-1,:], 
              cmap='viridis')
plt.colorbar()
plt.title("Depth")


plt.subplot(122)
splotter.triang.set_mask(None)
plt.tripcolor(splotter.triang, 
              facecolors = splotter.speed[-1,:], 
              cmap='viridis')
plt.colorbar()
plt.title("Speed");

# %%
sys.path.append('/home/ZhiLi/CRESTHH')
import crest_core

# %%
Rain= 1000;
Evap= 1.6;
RI =0;
RS =0;
SS0 =1.0;
SI0= 2.0;
W0= 5;
RainFact= 0.5;
Ksat= 0.2;
WM=200;
B= 0.4;
IM= 0.2;
KE= 0.6;
coeM= 0.2;
expM= 3;
coeR= 0.6;
coeS= 0.4;
KS= 0.8;
KI= 0.3;
timestep=1;

crest_core.model(Rain, Evap, RI, RS, SS0, SI0, W0,
                RainFact, Ksat, WM, B, IM, KE, coeM,
                expM, coeR, coeS, KS, KI, timestep)

# %%
import datetime

# %%
datetime.timedelta(hours=1) * 2
